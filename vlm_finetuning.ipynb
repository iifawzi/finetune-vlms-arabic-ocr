# %% [markdown]
# <a href="https://colab.research.google.com/github/iifawzi/finetune-vlms-arabic-ocr/blob/main/vlm_finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdf2image==1.17.0 pillow==12.1.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 48.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.50.0 requires pillow<12.0,>=8.0, but you have pillow 12.1.0 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from os.path import join
import random
from tqdm.auto import tqdm

from glob import globfrom
from pdf2image import convert_from_path
from PIL import Image

data_dir = "/gdrive/MyDrive/finetune-vlms"

# %%
def preprocess_image(image, max_width=600):

  gray_image = image.convert('L')

  if gray_image.width > max_width:
    ratio = max_width / gray_image.width
  pass


def convert_pdf_to_image(pdf_path, output_base_dir):

  pass
